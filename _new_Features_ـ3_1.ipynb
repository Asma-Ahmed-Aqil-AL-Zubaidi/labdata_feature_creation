# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma-Ahmed-Aqil-AL-Zubaidi/labdata_feature_creation/blob/main/_new_Features_%D9%803_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import warnings
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
import plotly.express as px
from tqdm import tqdm
import xgboost as xgb
from tqdm.auto import tqdm
from google.colab import drive
import os
import time
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# !ls "/content/drive/My Drive/EFasmaa"
# Out:
# df3_soum_data.csv

# %%
df3=pd.read_csv('/content/drive/My Drive/FEasmaa/df4_saved.csv')

# %%
df3.shape
# Out:
# (900000, 105)

# %% [markdown]
# # 1-Blood Pressure Features

# %% [markdown]
# # Pulse Pressure

# %%
df3["Pulse_Pressure"] = df3["Systolic Pressure"] - df3["Diastolic Pressure"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.09.00 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Mean Arterial Pressure (MAP)

# %%
df3["MAP"] = (df3["Systolic Pressure"] + 2 * df3["Diastolic Pressure"]) / 3

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.09.13 AM.png](data:image/png;base64,...)

# %% [markdown]
# # BP Ratio

# %%
df3["BP_Ratio"] = df3["Systolic Pressure"] / df3["Diastolic Pressure"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.09.17 AM.png](data:image/png;base64,...)

# %% [markdown]
# # 2-Kidney Function Features

# %%
df3["Urea_Creatinine_Ratio"] = df3["Urea in Serum"] / df3["Creatinine in Serum"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.22.41 AM.png](data:image/png;base64,...)

# %%
df3["BUN_eGFR_Ratio"] = df3["Blood Urea Nitrogen (BUN)"] / df3["Estimated Glomerular Filtration Rate(eGFR)"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.22.46 AM.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Lipid Profile Features

# %%
df3["Non_HDL_Cholesterol"] = df3["Cholesterol"] - df3["HDL Cholesterol"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.24.56 AM.png](data:image/png;base64,...)

# %%
df3["TG_HDL_Ratio"] = df3["Triglycerides (TG) in Serum"] / df3["HDL Cholesterol"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.25.01 AM.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Glucose Control Features

# %%
df3["EAG"] = (28.7 * df3["Hb A1c %"]) - 46.7

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.28.32 AM.png](data:image/png;base64,...)

# %%
df3["Glucose_HbA1c_Ratio"] = df3["Glucose in Plasma (Fasting)"] / df3["Hb A1c %"]

# %% [markdown]
# ![Screenshot 1446-09-25 at 7.28.35 AM.png](data:image/png;base64,...)

# %%
df3.isnull().sum().sum()
# Out:
# np.int64(37576155)

# %%
df3.shape
# Out:
# (900000, 114)
